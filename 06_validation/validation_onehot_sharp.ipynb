# %%
import pandas as pd

# %%
t1 = pd.read_parquet("../output/04_lasso_multivariate/data/bhs_complete_cases_n_lower_quartile_scored_x_one_hot_data.parquet")
t2 = pd.read_parquet("../output/04_lasso_multivariate/data/bhs_knn_impute_n_lower_quartile_scored_x_one_hot_data.parquet")
t3 = pd.read_parquet("../output/04_lasso_multivariate/data/bhs_knn_impute_only_x_one_hot_data.parquet")

# %%
t1.head(20)
# Out:
#     waist.0.0  hip.0.0  height_stand.0.0  height_seat.0.0  \
# 0        72.0     90.0             158.0            132.0
# 1        71.0     90.0             145.0            118.0
# 2        99.0    102.0             179.0            135.0
# 3        74.0     95.0             162.0            139.0
# 4       120.0    115.0             178.0            131.0
# 5        85.0     94.0             187.0            146.0
# 6        88.0     94.0             179.0            143.0
# 7       145.0    145.0             177.0            144.0
# 8       105.0    115.0             191.0            146.0
# 9        79.0    100.0             163.0            138.0
# 10       73.0     89.0             161.5            133.0
# 11       84.0     90.0             173.0            137.0
# 12       72.0     95.0             165.0            138.0
# 13       78.0     96.0             171.0            139.0
# 14      115.0    118.0             176.0            144.0
# ...

# %%
t2.head(20)
# Out:
#     waist.0.0  hip.0.0  height_stand.0.0  height_seat.0.0  \
# 0       113.0     99.0             181.0            143.0
# 1        69.0     90.0             162.0            134.0
# 2        84.0    108.0             164.0            140.0
# 3       102.0    104.0             174.0            142.0
# 4        97.0    101.0             173.0            142.0
# 5        72.0     90.0             158.0            132.0
# 6        71.0     90.0             145.0            118.0
# 7        99.0    102.0             179.0            135.0
# 8       104.0    100.0             165.0            136.0
# 9        74.0     95.0             162.0            139.0
# 10       93.0     98.0             169.0            138.0
# 11       96.0    108.0             182.0            144.0
# 12      120.0    115.0             178.0            131.0
# 13       85.0     94.0             187.0            146.0
# 14       67.0     89.0             168.0            128.0
# ...

# %%
t3.head(20)
# Out:
#     waist.0.0  hip.0.0  height_stand.0.0  height_seat.0.0  \
# 0       113.0     99.0             181.0            143.0
# 1        69.0     90.0             162.0            134.0
# 2        84.0    108.0             164.0            140.0
# 3       102.0    104.0             174.0            142.0
# 4        97.0    101.0             173.0            142.0
# 5        72.0     90.0             158.0            132.0
# 6        71.0     90.0             145.0            118.0
# 7        99.0    102.0             179.0            135.0
# 8       104.0    100.0             165.0            136.0
# 9        74.0     95.0             162.0            139.0
# 10       93.0     98.0             169.0            138.0
# 11       96.0    108.0             182.0            144.0
# 12      120.0    115.0             178.0            131.0
# 13       85.0     94.0             187.0            146.0
# 14       67.0     89.0             168.0            128.0
# ...
